#         3.01747823e-01, -1.77753945e+00,  3.56856732e-02,  4.84229917e-02,
#        -4.53283775e-01,  2.98221762e-01, -5.95708372e-01,  1.46583320e+00,
#         1.91067053e-02, -7.53643455e-01, -2.61341372e+00,  1.17669491e+00,
#         7.52717335e-01,  4.32655223e-01, -2.04253904e+00, -1.88678367e+00,
#         5.46723032e-01,  4.43298161e-01,  3.16171258e-01, -1.10320792e+00])

# %%
df = pd.DataFrame(randn(1000),index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])

# %%
df
# Out:
#                value
# 2019-06-07  1.058312
# 2019-06-08 -0.170244
# 2019-06-09 -0.245100
# 2019-06-10  1.937915
# 2019-06-11 -1.522100
# ...              ...
# 2022-02-26  0.295805
# 2022-02-27  1.002835
# 2022-02-28  0.861830
# 2022-03-01  1.350982
# 2022-03-02  0.425892
#
# [1000 rows x 1 columns]

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07 -0.082031
# 2019-06-08 -0.687042
# 2019-06-09  0.910253
# 2019-06-10 -2.517374
# 2019-06-11 -0.998869

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -1.134138
# 2019-06-08 -1.490270
# 2019-06-09 -1.953740
# 2019-06-10 -1.534284
# 2019-06-11 -3.187840

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -1.043214
# 2019-06-08    0.721693
# 2019-06-09   -0.131101
# 2019-06-10    1.179522
# 2019-06-11    0.633984
# Freq: D, dtype: float64

# %%
ts.head()
# Out:
# 2019-06-07   -1.043214
# 2019-06-08    0.721693
# 2019-06-09   -0.131101
# 2019-06-10    1.179522
# 2019-06-11    0.633984
# Freq: D, dtype: float64

# %%
ts.plot(figsize=(5,5))

# %%
plt.plot(ts)

# %%
ts
# Out:
# 2019-06-07    0.091833
# 2019-06-08   -0.448929
# 2019-06-09   -0.610547
# 2019-06-10   -0.836214
# 2019-06-11   -0.421815
#                 ...
# 2022-02-26    0.409846
# 2022-02-27    1.654632
# 2022-02-28   -1.233340
# 2022-03-01   -1.298884
# 2022-03-02    0.348891
# Freq: D, Length: 1000, dtype: float64

# %%
df.head()
# Out:
#                value
# 2019-06-07 -0.082031
# 2019-06-08 -0.687042
# 2019-06-09  0.910253
# 2019-06-10 -2.517374
# 2019-06-11 -0.998869

# %%
df.plot(kind ='line')

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0  1.091751  0.659024 -0.844989  1.004015
# 1  1.050571 -0.228485  0.325252 -1.005477
# 2  0.151609 -0.995779  0.026067  0.791837
# 3 -0.016696 -0.482657  0.958626  1.353511
# 4  1.865604 -0.982090 -0.175897  0.033510
# 5  0.575857 -0.504874 -0.420151  0.070612
# 6 -0.051699 -1.172501  0.308232  0.467488
# 7 -0.851313 -0.515041 -0.421565 -0.645609
# 8  0.622103  0.570797  3.033692 -0.562910
# 9  0.234697  0.850166 -1.281158 -0.041532

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['sepal_length'].plot.hist()

# %%
iris.plot(kind = 'hist', stacked = True, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = False, bins = 10)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'r', alpha = 0.7, figsize=(20,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017A2124D208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A216AE288>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017A2184FA08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A21888448>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df
# Out:
#           a         b         c         d
# 0 -0.853644 -0.803120  0.167032  0.532899
# 1 -0.948200  0.653701 -0.817223 -0.509526
# 2  0.147236 -0.361409 -0.706708 -0.386782
# 3  0.610484 -0.226329  1.168012 -1.123869
# 4 -1.657183 -1.944463  2.433751  0.637977
# 5 -1.275923  0.006308  0.093047  0.961360
# 6 -1.003499 -0.645808 -0.476702  0.495968
# 7  0.616025 -0.520040 -0.302793 -0.246821
# 8  0.662880 -0.815572  0.096013 -0.188605
# 9  0.302662  1.931527  0.357364 -0.013508

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df = iris

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', color = 'r')

# %%
ax = df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 30)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 50, C = 'sepal_width')

# %%
d
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df = iris.drop(['species'], axis = 1)
d = df.iloc[0]

d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (5,5))

# %%
df.head(3).T
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (15,15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000017A236EAC48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A23717A88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A236EAA08>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000015A3194C988>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000015A31969D48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000015A3199AC88>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8),  color = 'r',diagonal='kde')
plt.show()

# %%
ts.plot.kde()

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000017A23D48E88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A242CDBC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A2429B888>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A24337288>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
